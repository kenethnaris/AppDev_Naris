# %% [markdown]
# EXERCISE #1

# %%
#Print('Hello world!')
print('Hello World')
# the P in Print must be in small letter

# %%
#print'Hello world!')
print('Hello World')
# the open parenthesis is missing

# %%
#print('Hello world!)
print('Hello World')
# there must an apostrophe after the exclamation mark

# %%
#print('Hello world!'')
print('Hello World')
# The string Hello World must have only a pair on an apostrophe

# %%
#x = 43
#x = x + 1
#print(x)
44
# The output of this code is 44 because the x variable is 43 and added to 1

# %%
#x = 43
#x = X + 1
#print(x)
# There is an error is this code because the X variable is in the capital letter
