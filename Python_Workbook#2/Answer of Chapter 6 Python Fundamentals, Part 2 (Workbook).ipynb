# %% [markdown]
# Given the code below
#
# text = 'Business Analytics'
# What will the following expressions produce?
#
# text[4]
# text[2:4]
# text[:4]
# text[4:]
# text[-2]
# text[-4:-2]
# text[-2:]
# text[:-2]

# %% [markdown]
# Exercise Number 1:

# %%
# Answer in Exercise no. 1
text[4] - "n"
text[2:4] - "si"
text[:4] - "Busi"
text[4:] - "ness Analytics"
text[-2] - "c"
text[-4:-2] - "ti"
text[-2:] - "cs"
text[:-2] - "Business Analyti"

# %% [markdown]
# Exercise Number 2:

# %%
phrase = 'One Ring to rule them all'

# 'One '
substring1 = "'" + phrase[:4] + "'"

# 'Ring'
substring2 = "'" + phrase[4:8] + "'"

# 'all'
substring3 = "'" + phrase[-3:] + "'"

# 'them'
substring4 = "'" + phrase[17:21] + "'"

# 'One Ring to rule them all'
substring5 = "'" + phrase[:] + "'"

print(substring1)
print(substring2)
print(substring3)
print(substring4)
print(substring5)

# %% [markdown]
# CHALLENGE
# Write a program which repeatedly reads a full name, then does the following:
#
# strips the name of any trailing spaces
# capitalizes the first letter
# puts the rest into smaller letters

# %%
while True:
    name = input("Enter  your name:")
    fullname = name.strip()
    firstletter = name[0].upper()
    restletter = name[1:].lower()
    fullname = firstletter + restletter
    print(f"Cleared name:{fullname} ")
